# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from scipy.io import mmread
#X = csr_matrix(mmread('test.x.nm'))
#y = np.loadtxt('test.y.dat')

#para los datos con columna oscar
folder = "./movies-preproc/"
X_test = csr_matrix(mmread(folder+'ngrams-deprels-fp1-origin.runtime.budget.numscreen.ratings.seasons.stars/test.x.mm'))
y_test = np.loadtxt(folder+'ngrams-deprels-fp1-origin.runtime.budget.numscreen.ratings.seasons.stars/test.y.dat')

X_train = csr_matrix(mmread(folder+'ngrams-deprels-fp1-origin.runtime.budget.numscreen.ratings.seasons.stars/train.x.mm'))
y_train = np.loadtxt(folder+'ngrams-deprels-fp1-origin.runtime.budget.numscreen.ratings.seasons.stars/train.y.dat')

X_val = csr_matrix(mmread(folder+'ngrams-deprels-fp1-origin.runtime.budget.numscreen.ratings.seasons.stars/dev.x.mm'))
y_val = np.loadtxt(folder+'ngrams-deprels-fp1-origin.runtime.budget.numscreen.ratings.seasons.stars/dev.y.dat')

print "termino de cargar la data con menos caracteristicas (ya filtrada)"
# Out:
# termino de cargar la data con menos caracteristicas (ya filtrada)

# %%
X_train.shape
# Out:
# (1147, 145256)

# %%
y_train.shape
# Out:
# (1147,)

# %%
import matplotlib.pyplot as plt
plt.hist(np.log(y_train))
plt.show()

# %%
import sklearn.linear_model as lm
def MSE(y,yhat): return np.mean(np.power(y-yhat,2))

def best_alpha(alphas_, X,y, model, X_val,y_val):
    best_cv_mse = float("inf")
    for a in alphas_:
        model.set_params(alpha=a)
        mse =  MSE(model.fit(X,y).predict(X_val) , y_val)
        if mse < best_cv_mse:
            best_cv_mse = mse
            best_alpha = a
    return best_alpha

model = lm.LinearRegression(fit_intercept = False,n_jobs=-1)
model.fit(X_train,y_train)
best_score = model.score(X_test,y_test)
print "Score de regresion ordinaria: %f"%(best_score)

model = lm.Ridge(fit_intercept = False )
alphas_ = np.logspace(2,5, base = 10)
a = best_alpha(alphas_,X_train,y_train,model,X_val,y_val)
model.set_params(alpha=a)
model.fit(X_train,y_train)
score = model.score(X_test, y_test)
print "Score de regresion Ridge: %f , con alpha: %f"%(score,a)

model = lm.Lasso(fit_intercept = False)
alphas_ = np.logspace(8,4, base= 10)
a =  255954.792270 #best_alpha(alphas_, X_train,y_train, model, X_val,y_val)  #a = 255954.792270 
model.set_params(alpha=a)
model.fit(X_train,y_train)
score = model.score(X_test, y_test)
print "Score de regresion Lasso: %f , con alpha: %f"%(score,a)
# Out:
# Score de regresion ordinaria: 0.590314
# Score de regresion Ridge: 0.590674 , con alpha: 2222.996483
# Score de regresion Lasso: 0.577160 , con alpha: 255954.792270

# %% [markdown]
# alguien probo normalizando? porque baja tanto el score
# Sin intercept mejora ... (mas score) .. por que?

# %%
probar log..

# %%
model = lm.LinearRegression(fit_intercept = True, n_jobs=-1)
model.fit(X_train,np.log(y_train))
best_score = model.score(X_test,np.log(y_test))
print "Score de regresion ordinaria: %f"%(best_score)

model = lm.Ridge(fit_intercept = True )
alphas_ = np.logspace(2,5, base = 10)
a = best_alpha(alphas_,X_train,np.log(y_train),model,X_val,np.log(y_val))
print "Mejor alpha: ",a
model.set_params(alpha=a)
model.fit(X_train,np.log(y_train))
score = model.score(X_test, np.log(y_test))
print "Score de regresion Ridge: %f , con alpha: %f"%(score,a)

model = lm.Lasso(fit_intercept = True)
alphas_ = np.logspace(8,4, base= 10)
a = best_alpha(alphas_, X_train,np.log(y_train), model, X_val,np.log(y_val))  #a = 255954.792270 
print "mejor alpha: ",a
model.set_params(alpha=a)
model.fit(X_train,np.log(y_train))
score = model.score(X_test, np.log(y_test))
print "Score de regresion Lasso: %f , con alpha: %f"%(score,a)
# Out:
# Score de regresion ordinaria: 0.710517
# Mejor alpha:  115.139539933
# Score de regresion Ridge: 0.780941 , con alpha: 115.139540
# mejor alpha:  100000000.0
# Score de regresion Lasso: -0.050328 , con alpha: 100000000.000000

# %% [markdown]
# ### GRaficos

# %%
alphas_ = np.logspace(7,-2,base=10)
coefs = []
model = lm.Ridge(fit_intercept=False)
mse_test = []
mse_train = []
mse_val = []
for a in alphas_:
    model.set_params(alpha=a)
    model.fit(X_train, y_train)
    yhat_train = model.predict(X_train)
    yhat_val = model.predict(X_val)
    yhat_test = model.predict(X_test)
    mse_train.append(MSE(yhat_train,y_train))
    mse_test.append(MSE(yhat_test, y_test))
    mse_val.append(MSE(yhat_val,y_val))
import matplotlib.pylab as plt
ax = plt.gca()
ax.plot(alphas_,mse_train,label='train error Ridge')
ax.plot(alphas_,mse_val,label= 'cross-validation error Ridge')
ax.plot(alphas_,mse_test,label='test error Ridge')
plt.legend(loc=2)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])
plt.show()

# %%
alphas_ = np.logspace(8,-2,base=10)  # 8 a 0
coefs = []
model = lm.Lasso(fit_intercept=False, tol =0.0000001)
mse_test = []
mse_train = []
mse_val = []
for a in alphas_:
    model.set_params(alpha=a)
    model.fit(X_train, y_train)
    yhat_train = model.predict(X_train)
    yhat_val = model.predict(X_val)
    yhat_test = model.predict(X_test)
    mse_train.append(MSE(yhat_train,y_train))
    mse_test.append(MSE(yhat_test, y_test))
    mse_val.append(MSE(yhat_val,y_val))
import matplotlib.pylab as plt
ax = plt.gca()
ax.plot(alphas_,mse_train,label='train error Lasso')
ax.plot(alphas_,mse_val,label= 'cross-validation error Lasso')
ax.plot(alphas_,mse_test,label='test error Lasso')
plt.legend(loc=2)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])
plt.show()

# %%
import sklearn.linear_model as lm

model = lm.LinearRegression(fit_intercept = False,n_jobs=-1)
model.fit(X_train,y_train)

def MSE(y,yhat): return np.mean(np.power(y-yhat,2))

def fss(x, y,  x_val, y_val, k = 10000):
    p = x.shape[1]-1
    k = min(p, k)
    remaining = range(0, p)
    selected = [p]
    current_score = 0.0
    best_new_score = 0.0
    while remaining and len(selected)<=k :
        score_candidates = []
        for candidate in remaining:
            model = lm.LinearRegression(fit_intercept=False)
            indexes = selected + [candidate]
            x_train = x[:,indexes]
            
            mse_candidate = MSE(model.fit(x_train,y).predict(x_val[:,indexes]) , y_val)
            #mse_candidate = C_V(x_train,y, K=10)
            score_candidates.append((mse_candidate, candidate))
        score_candidates.sort()
        score_candidates[:] = score_candidates[::-1]
        best_new_score, best_candidate = score_candidates.pop() #el de menor error es el mejor candidato
        remaining.remove(best_candidate)
        selected.append(best_candidate)
        print "selected = %s ..."%names_x[best_candidate]
        print "totalvars=%d, mse = %f"%(len(indexes),best_new_score)
    return selected
sequence = fss(X_train,y_train,X_val,y_val)
print sequence
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-bc4fc672a9f2> in <module>()
#      31         print "totalvars=%d, mse = %f"%(len(indexes),best_new_score)
#      32     return selected
# ---> 33 sequence = fss(X_train,y_train,X_val,y_val)
#      34 print sequence
#
# <ipython-input-44-bc4fc672a9f2> in fss(x, y, x_val, y_val, k)
#      20             x_train = x[:,indexes]
#      21
# ---> 22             mse_candidate = MSE(model.fit(x_train,y).predict(x_val[:,indexes]) , y_val)
#      23             #mse_candidate = C_V(x_train,y, K=10)
#      24             score_candidates.append((mse_candidate, candidate))
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     495         if sp.issparse(X):
#     496             if y.ndim < 2:
# --> 497                 out = sparse_lsqr(X, y)
#     498                 self.coef_ = out[0]
#     499                 self._residues = out[3]
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/isolve/lsqr.pyc in lsqr(A, b, damp, atol, btol, conlim, iter_lim, show, calc_var)
#      96
#      97
# ---> 98 def lsqr(A, b, damp=0.0, atol=1e-8, btol=1e-8, conlim=1e8,
#      99          iter_lim=None, show=False, calc_var=False):
#     100     """Find the least-squares solution to a large, sparse, linear system
#
# KeyboardInterrupt:

# %% [markdown]
# ## Dataset con mas caract

# %%
X_test = csr_matrix(mmread(folder+'ngrams-deprels-origin.runtime.budget.numscreen.ratings.seasons/test.x.mm'))
y_test = np.loadtxt(folder+'ngrams-deprels-origin.runtime.budget.numscreen.ratings.seasons/test.y.dat')

X_train = csr_matrix(mmread(folder+'ngrams-deprels-origin.runtime.budget.numscreen.ratings.seasons/train.x.mm'))
y_train = np.loadtxt(folder+'ngrams-deprels-origin.runtime.budget.numscreen.ratings.seasons/train.y.dat')

X_val = csr_matrix(mmread(folder+'ngrams-deprels-origin.runtime.budget.numscreen.ratings.seasons/dev.x.mm'))
y_val = np.loadtxt(folder+'ngrams-deprels-origin.runtime.budget.numscreen.ratings.seasons/dev.y.dat')

print "termino de cargar la data"
# Out:
# termino de cargar la data

# %%
X_train.shape
# Out:
# (1147, 276222)

# %%
import sklearn.linear_model as lm

model = lm.LinearRegression(fit_intercept = False, n_jobs=-1)
model.fit(X_train,y_train)
best_score = model.score(X_test,y_test)
print "Score de regresion ordinaria: %f"%(best_score)

model = lm.Ridge(fit_intercept = False )
alphas_ = np.logspace(4,9, base = 10)
a = best_alpha(alphas_,X_train,y_train,model,X_val,y_val)
model.set_params(alpha=a)
model.fit(X_train,y_train)
score = model.score(X_test, y_test)
print "Score de regresion Ridge: %f , con alpha: %f"%(score,a)

model = lm.Lasso(fit_intercept = False ,tol = 0.0000001)
alphas_ = np.logspace(7,4, base= 10)
a = best_alpha(alphas_, X_train,y_train, model, X_val,y_val)  #a = 255954.792270 
model.set_params(alpha=a)
model.fit(X_train,y_train)
score = model.score(X_test, y_test)
print "Score de regresion Lasso: %f , con alpha: %f"%(score,a)
# Out:
# Score de regresion ordinaria: 0.206193
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-655076bc689f> in <module>()
#       8 model = lm.Ridge(fit_intercept = False )
#       9 alphas_ = np.logspace(4,9, base = 10)
# ---> 10 a = best_alpha(alphas_,X_train,y_train,model,X_val,y_val)
#      11 model.set_params(alpha=a)
#      12 model.fit(X_train,y_train)
#
# <ipython-input-33-d9ecac4412ab> in best_alpha(alphas_, X, y, model, X_val, y_val)
#       6     for a in alphas_:
#       7         model.set_params(alpha=a)
# ----> 8         mse =  MSE(model.fit(X,y).predict(X_val) , y_val)
#       9         if mse < best_cv_mse:
#      10             best_cv_mse = mse
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in fit(self, X, y, sample_weight)
#     663         self : returns an instance of self.
#     664         """
# --> 665         return super(Ridge, self).fit(X, y, sample_weight=sample_weight)
#     666
#     667
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in fit(self, X, y, sample_weight)
#     504                 max_iter=self.max_iter, tol=self.tol, solver=self.solver,
#     505                 random_state=self.random_state, return_n_iter=True,
# --> 506                 return_intercept=False)
#     507             self._set_intercept(X_offset, y_offset, X_scale)
#     508
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, random_state, return_n_iter, return_intercept)
#     389     n_iter = None
#     390     if solver == 'sparse_cg':
# --> 391         coef = _solve_sparse_cg(X, y, alpha, max_iter, tol, verbose)
#     392
#     393     elif solver == 'lsqr':
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in _solve_sparse_cg(X, y, alpha, max_iter, tol, verbose)
#      59             C = sp_linalg.LinearOperator(
#      60                 (n_samples, n_samples), matvec=mv, dtype=X.dtype)
# ---> 61             coef, info = sp_linalg.cg(C, y_column, tol=tol)
#      62             coefs[i] = X1.rmatvec(coef)
#      63         else:
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/isolve/iterative.pyc in cg(A, b, x0, tol, maxiter, xtype, M, callback)
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/_lib/_threadsafety.pyc in caller(func, *a, **kw)
#      44         def caller(func, *a, **kw):
#      45             with self:
# ---> 46                 return func(*a, **kw)
#      47         return scipy._lib.decorator.decorate(func, caller)
#      48
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/isolve/iterative.pyc in cg(A, b, x0, tol, maxiter, xtype, M, callback)
#     246         elif (ijob == 1):
#     247             work[slice2] *= sclr2
# --> 248             work[slice2] += sclr1*matvec(work[slice1])
#     249         elif (ijob == 2):
#     250             work[slice1] = psolve(work[slice2])
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in matvec(self, x)
#     217             raise ValueError('dimension mismatch')
#     218
# --> 219         y = self._matvec(x)
#     220
#     221         if isinstance(x, np.matrix):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in _matvec(self, x)
#     469
#     470     def _matvec(self, x):
# --> 471         return self.__matvec_impl(x)
#     472
#     473     def _rmatvec(self, x):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc in _mv(x)
#      42         def create_mv(curr_alpha):
#      43             def _mv(x):
# ---> 44                 return X1.matvec(X1.rmatvec(x)) + curr_alpha * x
#      45             return _mv
#      46     else:
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in rmatvec(self, x)
#     264             raise ValueError('dimension mismatch')
#     265
# --> 266         y = self._rmatvec(x)
#     267
#     268         if isinstance(x, np.matrix):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in _rmatvec(self, x)
#     286             raise NotImplementedError
#     287         else:
# --> 288             return self.H.matvec(x)
#     289
#     290     def matmat(self, X):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in matvec(self, x)
#     217             raise ValueError('dimension mismatch')
#     218
# --> 219         y = self._matvec(x)
#     220
#     221         if isinstance(x, np.matrix):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in _matvec(self, x)
#     184         will define matrix-vector multiplication as well.
#     185         """
# --> 186         return self.matmat(x.reshape(-1, 1))
#     187
#     188     def matvec(self, x):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in matmat(self, X)
#     324                              % (self.shape, X.shape))
#     325
# --> 326         Y = self._matmat(X)
#     327
#     328         if isinstance(Y, np.matrix):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/linalg/interface.pyc in _matmat(self, X)
#     608
#     609     def _matmat(self, X):
# --> 610         return self.A.dot(X)
#     611
#     612     def _adjoint(self):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in dot(self, other)
#     300
#     301         """
# --> 302         return self * other
#     303
#     304     def power(self, n, dtype=None):
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/base.pyc in __mul__(self, other)
#     356                 return self._mul_vector(other)
#     357             elif other.shape == (N, 1):
# --> 358                 return self._mul_vector(other.ravel()).reshape(M, 1)
#     359             elif other.ndim == 2 and other.shape[0] == N:
#     360                 return self._mul_multivector(other)
#
# /home/panshop/anaconda2/lib/python2.7/site-packages/scipy/sparse/compressed.pyc in _mul_vector(self, other)
#     496         # csr_matvec or csc_matvec
#     497         fn = getattr(_sparsetools,self.format + '_matvec')
# --> 498         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     499
#     500         return result
#
# KeyboardInterrupt:
